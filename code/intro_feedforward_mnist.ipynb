# %% [markdown]
# <a href="https://colab.research.google.com/github/LeslieF03/MathAIspring2026-Tareas/blob/main/code/intro_feedforward_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MNIST digits recognition
# ## Feedforward network with 2 hidden layers
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eduenez/MathAIspring2026UTSA/blob/main/code/intro_feedforward_mnist.ipynb)
#
# Uses [Keras](https://keras.io/) with [JAX](https://github.com/jax-ml/jax) as NN engine.

# %%
# Install Jax running on Google/Colab Tensor Processing Units
# !pip install "jax[tpu]"

# Install Keras
# !pip install keras-cv
# !pip install keras-hub
# !pip install keras
# Out:
# Requirement already satisfied: jax[tpu] in /usr/local/lib/python3.12/dist-packages (0.7.2)
# Requirement already satisfied: jaxlib<=0.7.2,>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (0.7.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (0.5.4)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (1.16.3)
# Requirement already satisfied: libtpu==0.0.23 in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (0.0.23)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from jax[tpu]) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->jax[tpu]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->jax[tpu]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->jax[tpu]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->jax[tpu]) (2026.5.20)
# Requirement already satisfied: keras-cv in /usr/local/lib/python3.12/dist-packages (0.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-cv) (26.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from keras-cv) (2025.11.3)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.12/dist-packages (from keras-cv) (4.9.10)
# Requirement already satisfied: keras-core in /usr/local/lib/python3.12/dist-packages (from keras-cv) (0.1.7)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (from keras-cv) (1.0.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (0.1.23)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (4.67.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (3.16.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (0.1.10)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (0.8.3)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (1.14.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (4.3.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (5.29.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (18.1.0)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (1.17.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (3.3.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (2.2.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (0.8.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (2025.3.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (4.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (2026.5.20)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree->keras-core->keras-cv) (26.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-core->keras-cv) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-core->keras-cv) (2.20.0)
# Requirement already satisfied: docstring-parser~=0.15 in /usr/local/lib/python3.12/dist-packages (from simple_parsing->tensorflow-datasets->keras-cv) (0.18.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.12/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.75.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Requirement already satisfied: keras-hub in /usr/local/lib/python3.12/dist-packages (0.26.0)
# Requirement already satisfied: keras>=3.13 in /usr/local/lib/python3.12/dist-packages (from keras-hub) (3.13.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras-hub) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras-hub) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-hub) (26.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from keras-hub) (2025.11.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras-hub) (13.9.4)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (from keras-hub) (1.0.1)
# Requirement already satisfied: tensorflow-text in /usr/local/lib/python3.12/dist-packages (from keras-hub) (2.20.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.13->keras-hub) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.13->keras-hub) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.13->keras-hub) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.13->keras-hub) (0.5.4)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-hub) (0.1.23)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-hub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-hub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-hub) (4.67.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-hub) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-hub) (2.20.0)
# Requirement already satisfied: tensorflow<2.21,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-text->keras-hub) (2.20.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kagglesdk<1.0,>=0.1.22->kagglehub->keras-hub) (5.29.6)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras-hub) (0.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (1.81.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (2.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-hub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-hub) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-hub) (2026.5.20)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (0.47.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20.0->tensorflow-text->keras-hub) (3.0.3)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (3.13.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras) (26.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# Import installed software and put things in place
import os
os.environ["KERAS_BACKEND"] = "jax"
import matplotlib.pyplot as plt
import numpy as np
from keras import layers
from keras import ops
import keras
# print(keras.__version__)
# print(keras.backend.backend())

# %% [markdown]
# # Model `model` below is a feedforward network
#
# - Input layer of dimension `784` (each MNIST character is encoded as a 28-by-28 image having `28*28 = 784` pixels when “flattened”).
# - Dense (“fully connected”) hidden layer 1 of dimension `64`.
# - Dense (“fully connected”) hidden layer 2 of dimension `64`.
# - Dense (“fully connected”) output layer of dimension `10`.
#
# The `model` is then created as a Keras model object.
# It will process `784`-dimensional inputs and generate `10`-dimensional outputs.
#
# - Each of the 64 dimensions of the 1st layer has 784 linear cofficients plus 1 bias = 785 parameters, for a total of 64*785 = `50,240` parameters.
# - Each of the 64 dimensions of the 1st layer has 64 linear cofficients plus 1 bias = 65 parameters, for a total of 64*65 = `4,160` parameters.
# - Each of the 10 dimensions of the 1st layer has 64 linear cofficients plus 1 bias = 65 parameters, for a total of 10*65 = `650` parameters.
#
# Therefore, `model` has `50,240 + 4,160 + 650 = 55,050` total parameters.
#
# **Note:** The MNIST data set has *not* yet been loaded at all!
# Absolutely *no* data proper has been used at this point.

# %%
dim_hl_1 = 64 # @param {type: "integer"}
dim_hl_2 = 64 # @param {type: "integer"}

inputs = keras.Input(shape=(784,))  # Input layer shape for flatened MNIST images
hidden1 = layers.Dense(dim_hl_1, activation="relu")(inputs)  # First hidden layer
hidden2 = layers.Dense(dim_hl_2, activation="relu")(hidden1)  # Second hidden layer
# Output layer must have dimension 10 = number of categories.
outputs = layers.Dense(10)(hidden2)  # No ReLu here b/c output is "logits".
model = keras.Model(inputs=inputs, outputs=outputs, name="mnist_model")
model.summary()
# Out:
# Model: "mnist_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 55,050 (215.04 KB)
#  Trainable params: 55,050 (215.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
keras.utils.plot_model(model, "feedforward_model.png")

# %%
keras.utils.plot_model(model, "feedforward_model_with_shape_info.png", show_shapes=True)

# %% [markdown]
# # Load MNIST dataset
#
#   Each single MNIST image of a handwritten digit 0, 1, 2, …, 8, 9 is encoded as a matrix of size `28*28` whose entries are 8-bit unsigned integers (i.e., each entry is an integer in the range from `0` to `2^8 - 1 = 255`).
# Each integer represents the grayscale color of a pixel (0 = black, 255 = white).
#
# For reasons of computational efficiency and numerical stability, the grayscale is rescaled to be a floating-point (decimal) number in the interval `[0, 1)`, and the 28-by-28 matrix is “flattened” to be a single (column) vector of `28*28 = 784` decimal such entries, each a `float32` (32-bit floating point number).
#
# Since the training set consists of 60,000 such digit images, each effectively a column vector of size 784, it gives a large matrix `x_train` of size `60,000 × 784`; similarly, the test set of 10,000 images gives a `10,000 × 784` matrix `x_test`.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.reshape(60000, 784).astype("float32") / 255
x_test = x_test.reshape(10000, 784).astype("float32") / 255

# %% [markdown]
# # Compile and train the model
#
# By default, when a model is “compiled”, its parameters are initialized randomly and uniformly (with zero mean and variance determined by the input and output dimensions at each layer—but otherwise not of immediate interest to us right now).
#
# When `model` is applied to an input of size `m × 764`, it is applied to *each* of the `m` columns, one at a time—because `model` only accepts as input a (column) vector of size 764, and outputs one of size 10;
# in other words, `model` sees those `m` *rows* as completely independent of each other.
# The result is a matrix of size `m × 10`.
#
# `batch_size=64` means that each “training step” of the model uses *only* a randomly-chosen batch of (about) `m = 64` inputs (i.e., 64 rows of `x_train`) at a time, until all 60,000 rows are exhausted.
# This called a (single) “epoch”, which consists of (about) `60,000/64 ≈ 934` such steps.
# The process is restarted (bringing back all 60,000 rows of `x_train`) and carried out a total number of epochs `num_epochs = 20`.
#
# (Actually, `validation_split=0.2` means that 20% of the training data is excluded during each epoch, so an epoch therefore only consists of about `0.8 * 934 ≈ 747` batches of `≈ 64` training images each.)
#
# Keras has various built-in optimization algorithms; this model's algorithm is the *root mean-square propagation* or `RMSprop`.
#
# The accuracy of the model is quantified using a "loss" function. A larger loss means less accuracy, so the goal as the model is trained is *reducing* or “minimizing” the loss.
# (The loss function used in this implementation is called *categorical cross-entropy*. Entropy and related quantities will be introduced later in the semester.)

# %%
num_epochs = 20  # @param {type: "integer"}

model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=keras.optimizers.RMSprop(),
    metrics=["accuracy"],
)

history = model.fit(x_train, y_train, batch_size=64, epochs=20, validation_split=0.2)

# Fix: verbose should be an integer, not a string
test_scores = model.evaluate(x_test, y_test, verbose=2)
print("Test loss:", test_scores[0])
print("Test accuracy:", test_scores[1])
# Out:
# Epoch 1/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9030 - loss: 0.3477 - val_accuracy: 0.9448 - val_loss: 0.1881
# Epoch 2/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9511 - loss: 0.1647 - val_accuracy: 0.9563 - val_loss: 0.1477
# Epoch 3/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9636 - loss: 0.1203 - val_accuracy: 0.9623 - val_loss: 0.1279
# Epoch 4/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9712 - loss: 0.0964 - val_accuracy: 0.9666 - val_loss: 0.1088
# Epoch 5/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9753 - loss: 0.0793 - val_accuracy: 0.9688 - val_loss: 0.1119
# Epoch 6/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9791 - loss: 0.0671 - val_accuracy: 0.9705 - val_loss: 0.0998
# Epoch 7/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9816 - loss: 0.0587 - val_accuracy: 0.9718 - val_loss: 0.1007
# Epoch 8/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9844 - loss: 0.0515 - val_accuracy: 0.9689 - val_loss: 0.1135
# Epoch 9/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9863 - loss: 0.0447 - val_accuracy: 0.9707 - val_loss: 0.1136
# Epoch 10/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9876 - loss: 0.0395 - val_accuracy: 0.9723 - val_loss: 0.1094
# Epoch 11/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9892 - loss: 0.0343 - val_accuracy: 0.9722 - val_loss: 0.1089
# Epoch 12/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9908 - loss: 0.0300 - val_accuracy: 0.9716 - val_loss: 0.1202
# Epoch 13/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9917 - loss: 0.0274 - val_accuracy: 0.9698 - val_loss: 0.1201
# Epoch 14/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9924 - loss: 0.0237 - val_accuracy: 0.9724 - val_loss: 0.1180
# Epoch 15/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9934 - loss: 0.0206 - val_accuracy: 0.9731 - val_loss: 0.1241
# Epoch 16/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0190 - val_accuracy: 0.9752 - val_loss: 0.1219
# Epoch 17/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9947 - loss: 0.0170 - val_accuracy: 0.9746 - val_loss: 0.1311
# Epoch 18/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9948 - loss: 0.0155 - val_accuracy: 0.9740 - val_loss: 0.1342
# Epoch 19/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 0.9732 - val_loss: 0.1402
# Epoch 20/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9961 - loss: 0.0127 - val_accuracy: 0.9721 - val_loss: 0.1537
# 313/313 - 1s - 2ms/step - accuracy: 0.9751 - loss: 0.1347
# Test loss: 0.13467110693454742
# Test accuracy: 0.9750999808311462

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# The code below randomly chooses 5 of the 10,000 images in the test set and applies `model` to assign a label (0, 1, …, 9) using a straightforward likelihood maximization procedure.
# Very few images in the test set should be misclassified:
# the `True` and `Pred`icted labels should be in agreement.

# %%
# Select a few random indices from the test set
num_samples = 5
indices = np.random.choice(len(x_test), num_samples, replace=False)

plt.figure(figsize=(10, 2))
for i, idx in enumerate(indices):
    img = x_test[idx]
    # If images are flattened, reshape to 28x28
    if img.shape[-1] != 28:
        img = img.reshape(28, 28)
    plt.subplot(1, num_samples, i + 1)
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    # Predict label and compare with true label.
    pred = model.predict(np.expand_dims(x_test[idx], axis=0), verbose=0)
    pred_label = np.argmax(pred, axis=1)[0]
    true_label = y_test[idx]
    plt.title(f"True: {true_label}\nPred: {pred_label}")
plt.tight_layout()
plt.show()

# %% [markdown]
# Experiments with parameters

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape(60000, 784).astype("float32") / 255
x_test = x_test.reshape(10000, 784).astype("float32") / 255

experimentos = [
    {"dim_hl_1": 32, "dim_hl_2": 16, "num_epochs": 10},
    {"dim_hl_1": 64, "dim_hl_2": 32, "num_epochs": 10},
    {"dim_hl_1": 64, "dim_hl_2": 64, "num_epochs": 20},
    {"dim_hl_1": 128, "dim_hl_2": 64, "num_epochs": 30}
]

resultados = []

for i, exp in enumerate(experimentos):
    print(f"Ejecutando Experimento {i+1}: dim1={exp['dim_hl_1']}, dim2={exp['dim_hl_2']}, épocas={exp['num_epochs']}...")

    inputs = keras.Input(shape=(784,))
    hidden1 = layers.Dense(exp["dim_hl_1"], activation="relu")(inputs)
    hidden2 = layers.Dense(exp["dim_hl_2"], activation="relu")(hidden1)
    outputs = layers.Dense(10)(hidden2)
    model = keras.Model(inputs=inputs, outputs=outputs)

    # Compilar
    model.compile(
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        optimizer=keras.optimizers.RMSprop(),
        metrics=["accuracy"],
    )

    history = model.fit(
        x_train, y_train,
        batch_size=64,
        epochs=exp["num_epochs"],
        validation_split=0.2,
        verbose=0
    )

    test_scores = model.evaluate(x_test, y_test, verbose=0)

    resultados.append({
        "Exp": i + 1,
        "dim_hl_1": exp["dim_hl_1"],
        "dim_hl_2": exp["dim_hl_2"],
        "Épocas": exp["num_epochs"],
        "Train Loss": round(history.history['loss'][-1], 4),
        "Train Acc (%)": round(history.history['accuracy'][-1] * 100, 2),
        "Val Loss": round(history.history['val_loss'][-1], 4),
        "Val Acc (%)": round(history.history['val_accuracy'][-1] * 100, 2),
        "Test Loss": round(test_scores[0], 4),
        "Test Acc (%)": round(test_scores[1] * 100, 2)
    })

df_resultados = pd.DataFrame(resultados)

print("\n" + "="*80)
print("TABLA DE RESULTADOS")
print("="*80)

# display() es una función nativa de IPython/Colab que formatea DataFrames como tablas HTML
display(df_resultados)
# Out:
# Ejecutando Experimento 1: dim1=32, dim2=16, épocas=10...
# Ejecutando Experimento 2: dim1=64, dim2=32, épocas=10...
# Ejecutando Experimento 3: dim1=64, dim2=64, épocas=20...
# Ejecutando Experimento 4: dim1=128, dim2=64, épocas=30...
#
# ================================================================================
# TABLA FINAL DE RESULTADOS
# ================================================================================
#    Exp  dim_hl_1  dim_hl_2  Épocas  Train Loss  Train Acc (%)  Val Loss  \
# 0    1        32        16      10      0.0883          97.32    0.1334
# 1    2        64        32      10      0.0456          98.62    0.1060
# 2    3        64        64      20      0.0106          99.67    0.1358
# 3    4       128        64      30      0.0002          99.99    0.1648
#
#    Val Acc (%)  Test Loss  Test Acc (%)
# 0        96.13     0.1250         96.30
# 1        97.30     0.0969         97.40
# 2        97.56     0.1255         97.77
# 3        98.00     0.1481         98.11

# %% [markdown]
# - First, we observe evidence of **overfitting**, since as the number of neurons and the training time (more epochs) increase, the model begins to memorize the data rather than generalize from it. This is evident when comparing the loss and accuracy metrics.
#
# - Comparing **Experiment 2** with **Experiment 4**, the number of epochs is tripled and much denser layers (128 and 64 neurons) are used. This results in a significant increase in computational cost. However, the gain in final performance (**Test Accuracy**) is minimal, increasing by only **0.71%** (from **97.40%** to **98.11%**).
#
# - **Experiment 2** was likely the best-performing configuration, as it achieved the lowest **test loss** and **validation loss**, while maintaining a very high **test accuracy** without imposing such a heavy computational burden.
